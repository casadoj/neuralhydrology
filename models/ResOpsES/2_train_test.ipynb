# %% [markdown]
# # LSTM ResOps-ES: training & testing
# ***
#
# ***Author:** Chus Casado Rodríguez*<br>
# ***Date:** 16-04-2024*<br>
#
# **Introduction:**<br>
# This _notebook_ trains and tests an LSTM model to reproduce reservoir storage.
#
# **Por hacer**:

# %%
import sys
sys.path.append('../..')
# import pickle
import pandas as pd
from pathlib import Path
import torch
from tqdm.notebook import tqdm

from neuralhydrology.utils.config import Config
from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run

from model_utils import *

# %% [markdown]
# ### Configuración

# %%
# cargar archivo de configuración
config_file = Path('config_V_lstm64_fc32_do05.yml')
cfg = Config(config_file)

target = cfg.target_variables[0]

print(cfg.experiment_name)
print('epochs:', cfg.epochs, sep='\t\t')
print('hidden size:', cfg.hidden_size, sep='\t')
print('batch size:', cfg.batch_size, sep='\t')
print('dropout:', cfg.output_dropout, sep='\t')
print('clip gradients:', cfg.clip_gradient_norm, sep='\t')
# Out:
# V_lstm64_fc32_do05
# epochs:		30
# hidden size:	64
# batch size:	128
# dropout:	0.5
# clip gradients:	1

# %%
# simulación del entrenamiento y evaluación de todas las épocas?
run_all = True

# %% [markdown]
# ### Entrenamiento

# %%
if torch.cuda.is_available():
    print('CUDA available')
    start_run(config_file=config_file)
else:
    print('Running training on the CPU')
    start_run(config_file=config_file, gpu=-1)
# Out:
# CUDA available
# 2024-05-03 16:57:54,712: Logging to /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/output.log initialized.
# 2024-05-03 16:57:54,713: ### Folder structure created at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754
# 2024-05-03 16:57:54,714: ### Run configurations for V_lstm64_fc32_do05
# 2024-05-03 16:57:54,715: experiment_name: V_lstm64_fc32_do05
# 2024-05-03 16:57:54,716: run_dir: /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754
# 2024-05-03 16:57:54,717: train_basin_file: data/sample_train.txt
# 2024-05-03 16:57:54,718: validation_basin_file: data/sample_validation.txt
# 2024-05-03 16:57:54,719: test_basin_file: None
# 2024-05-03 16:57:54,719: per_basin_train_periods_file: data/periods_train.pkl
# 2024-05-03 16:57:54,720: per_basin_validation_periods_file: data/periods_validation.pkl
# 2024-05-03 16:57:54,721: per_basin_test_periods_file: None
# 2024-05-03 16:57:54,722: seed: 0
# 2024-05-03 16:57:54,723: device: cuda:0
# 2024-05-03 16:57:54,724: validate_every: 1
# 2024-05-03 16:57:54,725: validate_n_random_basins: 100
# 2024-05-03 16:57:54,726: cache_validation_data: True
# 2024-05-03 16:57:54,726: metrics: ['KGE']
# 2024-05-03 16:57:54,727: model: cudalstm
# 2024-05-03 16:57:54,728: checkpoint_path: None
# 2024-05-03 16:57:54,729: head: regression
# 2024-05-03 16:57:54,730: output_activation: linear
# 2024-05-03 16:57:54,730: statics_embedding: {'type': 'fc', 'hiddens': [32], 'activation': 'tanh', 'dropout': 0.5}
# 2024-05-03 16:57:54,731: dynamics_embedding: {'type': 'fc', 'hiddens': [32], 'activation': 'tanh', 'dropout': 0.5}
# 2024-05-03 16:57:54,732: hidden_size: 64
# 2024-05-03 16:57:54,733: initial_forget_bias: 3
# 2024-05-03 16:57:54,734: output_dropout: 0.5
# 2024-05-03 16:57:54,735: optimizer: Adam
# 2024-05-03 16:57:54,735: loss: NSE
# 2024-05-03 16:57:54,736: regularization: None
# 2024-05-03 16:57:54,737: learning_rate: {0: 0.001, 10: 0.0005, 20: 0.0001}
# 2024-05-03 16:57:54,738: batch_size: 128
# 2024-05-03 16:57:54,739: epochs: 30
# 2024-05-03 16:57:54,740: target_noise_std: 0
# 2024-05-03 16:57:54,741: clip_gradient_norm: 1
# 2024-05-03 16:57:54,741: predict_last_n: 1
# 2024-05-03 16:57:54,742: seq_length: 365
# 2024-05-03 16:57:54,743: num_workers: 32
# 2024-05-03 16:57:54,744: log_interval: 10
# 2024-05-03 16:57:54,745: log_tensorboard: True
# 2024-05-03 16:57:54,745: log_n_figures: 2
# 2024-05-03 16:57:54,746: save_weights_every: 1
# 2024-05-03 16:57:54,747: save_validation_results: True
# 2024-05-03 16:57:54,748: dataset: generic
# 2024-05-03 16:57:54,749: data_dir: /eos/jeodpp/home/users/casadje/data/ResOpsES
# 2024-05-03 16:57:54,750: save_train_data: True
# 2024-05-03 16:57:54,751: train_data_file: None
# 2024-05-03 16:57:54,752: dynamic_inputs: ['inflow_efas5', 'evapo_point_emo1', 'precip_point_emo1', 'temp_areal_emo1', 'year', 'month', 'dayofweek']
# 2024-05-03 16:57:54,752: target_variables: ['volume']
# 2024-05-03 16:57:54,753: clip_targets_to_zero: ['volume']
# 2024-05-03 16:57:54,754: static_attributes: ['AREA_SKM', 'CAP_MCM', 'CATCH_SKM', 'DAM_HGT_M', 'DOD_M', 'DOR', 'ELEV_MASL', 'LAT', 'LON']
# 2024-05-03 16:57:54,755: additional_feature_files: None
# 2024-05-03 16:57:54,756: evolving_attributes: None
# 2024-05-03 16:57:54,757: use_basin_id_encoding: False
# 2024-05-03 16:57:54,758: number_of_basins: 20
# 2024-05-03 16:57:54,758: train_dir: /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/train_data
# 2024-05-03 16:57:54,759: img_log_dir: /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/img_log
# 2024-05-03 16:57:54,810: ### Device cuda:0 will be used for training
# 2024-05-03 16:57:55,902: Loading basin data into xarray data set.
# 100% 20/20 [00:00<00:00, 22.41it/s]
# 2024-05-03 16:57:57,025: Calculating target variable stds per basin
# 100% 20/20 [00:00<00:00, 1226.40it/s]
# 2024-05-03 16:57:57,065: Create lookup table and convert to pytorch tensor
# 100% 20/20 [00:03<00:00,  5.04it/s]
# # Epoch 1: 100% 1637/1637 [00:27<00:00, 58.72it/s, Loss: 3.5781]
# 2024-05-03 16:58:33,431: Epoch 1 average loss: avg_loss: 5.18338, avg_total_loss: 5.18338
# # Validation: 100% 8/8 [00:04<00:00,  1.92it/s]
# 2024-05-03 16:58:38,534: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch001/validation_metrics.csv
# 2024-05-03 16:58:38,549: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch001/validation_results.p
# 2024-05-03 16:58:38,551: Epoch 1 average validation loss: 19.79714 -- Median validation metrics: avg_loss: 19.79714, KGE: 0.01873
# # Epoch 2: 100% 1637/1637 [00:26<00:00, 61.18it/s, Loss: 5.8815]
# 2024-05-03 16:59:05,313: Epoch 2 average loss: avg_loss: 3.70299, avg_total_loss: 3.70299
# # Validation: 100% 8/8 [00:02<00:00,  2.85it/s]
# 2024-05-03 16:59:08,964: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch002/validation_metrics.csv
# 2024-05-03 16:59:08,980: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch002/validation_results.p
# 2024-05-03 16:59:08,982: Epoch 2 average validation loss: 19.90625 -- Median validation metrics: avg_loss: 19.90625, KGE: 0.08819
# # Epoch 3: 100% 1637/1637 [00:27<00:00, 59.95it/s, Loss: 3.1124]
# 2024-05-03 16:59:36,293: Epoch 3 average loss: avg_loss: 3.18832, avg_total_loss: 3.18832
# # Validation: 100% 8/8 [00:02<00:00,  2.87it/s]
# 2024-05-03 16:59:39,954: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch003/validation_metrics.csv
# 2024-05-03 16:59:39,968: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch003/validation_results.p
# 2024-05-03 16:59:39,970: Epoch 3 average validation loss: 19.53890 -- Median validation metrics: avg_loss: 19.53890, KGE: 0.04393
# # Epoch 4: 100% 1637/1637 [00:26<00:00, 61.18it/s, Loss: 4.2422]
# 2024-05-03 17:00:06,733: Epoch 4 average loss: avg_loss: 2.91165, avg_total_loss: 2.91165
# # Validation: 100% 8/8 [00:02<00:00,  2.82it/s]
# 2024-05-03 17:00:10,444: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch004/validation_metrics.csv
# 2024-05-03 17:00:10,457: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch004/validation_results.p
# 2024-05-03 17:00:10,458: Epoch 4 average validation loss: 21.24378 -- Median validation metrics: avg_loss: 21.24378, KGE: 0.13058
# # Epoch 5: 100% 1637/1637 [00:27<00:00, 60.02it/s, Loss: 2.4752]
# 2024-05-03 17:00:37,738: Epoch 5 average loss: avg_loss: 2.68239, avg_total_loss: 2.68239
# # Validation: 100% 8/8 [00:02<00:00,  2.86it/s]
# 2024-05-03 17:00:41,389: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch005/validation_metrics.csv
# 2024-05-03 17:00:41,402: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch005/validation_results.p
# 2024-05-03 17:00:41,404: Epoch 5 average validation loss: 22.88301 -- Median validation metrics: avg_loss: 22.88301, KGE: 0.05953
# # Epoch 6: 100% 1637/1637 [00:27<00:00, 60.32it/s, Loss: 1.9516]
# 2024-05-03 17:01:08,550: Epoch 6 average loss: avg_loss: 2.51985, avg_total_loss: 2.51985
# # Validation: 100% 8/8 [00:02<00:00,  2.84it/s]
# 2024-05-03 17:01:12,302: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch006/validation_metrics.csv
# 2024-05-03 17:01:12,319: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch006/validation_results.p
# 2024-05-03 17:01:12,321: Epoch 6 average validation loss: 22.61617 -- Median validation metrics: avg_loss: 22.61617, KGE: 0.12074
# # Epoch 7: 100% 1637/1637 [00:27<00:00, 59.00it/s, Loss: 2.1711]
# 2024-05-03 17:01:40,070: Epoch 7 average loss: avg_loss: 2.40691, avg_total_loss: 2.40691
# # Validation: 100% 8/8 [00:03<00:00,  2.63it/s]
# 2024-05-03 17:01:44,005: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch007/validation_metrics.csv
# 2024-05-03 17:01:44,021: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch007/validation_results.p
# 2024-05-03 17:01:44,023: Epoch 7 average validation loss: 22.81646 -- Median validation metrics: avg_loss: 22.81646, KGE: 0.01830
# # Epoch 8: 100% 1637/1637 [00:26<00:00, 62.40it/s, Loss: 1.0293]
# 2024-05-03 17:02:10,260: Epoch 8 average loss: avg_loss: 2.30743, avg_total_loss: 2.30743
# # Validation: 100% 8/8 [00:02<00:00,  2.85it/s]
# 2024-05-03 17:02:13,903: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch008/validation_metrics.csv
# 2024-05-03 17:02:13,918: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch008/validation_results.p
# 2024-05-03 17:02:13,919: Epoch 8 average validation loss: 23.39460 -- Median validation metrics: avg_loss: 23.39460, KGE: -0.02303
# # Epoch 9: 100% 1637/1637 [00:26<00:00, 61.71it/s, Loss: 3.1408]
# 2024-05-03 17:02:40,451: Epoch 9 average loss: avg_loss: 2.23778, avg_total_loss: 2.23778
# # Validation: 100% 8/8 [00:02<00:00,  2.78it/s]
# 2024-05-03 17:02:44,175: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch009/validation_metrics.csv
# 2024-05-03 17:02:44,192: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch009/validation_results.p
# 2024-05-03 17:02:44,195: Epoch 9 average validation loss: 21.81384 -- Median validation metrics: avg_loss: 21.81384, KGE: 0.02822
# 2024-05-03 17:02:44,196: Setting learning rate to 0.0005
# # Epoch 10: 100% 1637/1637 [00:27<00:00, 59.32it/s, Loss: 1.9604]
# 2024-05-03 17:03:11,797: Epoch 10 average loss: avg_loss: 2.01153, avg_total_loss: 2.01153
# # Validation: 100% 8/8 [00:02<00:00,  2.85it/s]
# 2024-05-03 17:03:15,450: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch010/validation_metrics.csv
# 2024-05-03 17:03:15,462: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch010/validation_results.p
# 2024-05-03 17:03:15,463: Epoch 10 average validation loss: 22.46727 -- Median validation metrics: avg_loss: 22.46727, KGE: 0.11493
# # Epoch 11: 100% 1637/1637 [00:27<00:00, 59.73it/s, Loss: 2.9758]
# 2024-05-03 17:03:42,875: Epoch 11 average loss: avg_loss: 1.92648, avg_total_loss: 1.92648
# # Validation: 100% 8/8 [00:02<00:00,  2.88it/s]
# 2024-05-03 17:03:46,486: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch011/validation_metrics.csv
# 2024-05-03 17:03:46,502: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch011/validation_results.p
# 2024-05-03 17:03:46,503: Epoch 11 average validation loss: 23.04588 -- Median validation metrics: avg_loss: 23.04588, KGE: 0.02368
# # Epoch 12: 100% 1637/1637 [00:27<00:00, 60.34it/s, Loss: 4.2510]
# 2024-05-03 17:04:13,637: Epoch 12 average loss: avg_loss: 1.89528, avg_total_loss: 1.89528
# # Validation: 100% 8/8 [00:02<00:00,  2.82it/s]
# 2024-05-03 17:04:17,312: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch012/validation_metrics.csv
# 2024-05-03 17:04:17,327: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch012/validation_results.p
# 2024-05-03 17:04:17,329: Epoch 12 average validation loss: 24.15795 -- Median validation metrics: avg_loss: 24.15795, KGE: 0.01192
# # Epoch 13: 100% 1637/1637 [00:27<00:00, 59.72it/s, Loss: 2.0530]
# 2024-05-03 17:04:44,745: Epoch 13 average loss: avg_loss: 1.86009, avg_total_loss: 1.86009
# # Validation: 100% 8/8 [00:02<00:00,  2.78it/s]
# 2024-05-03 17:04:48,468: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch013/validation_metrics.csv
# 2024-05-03 17:04:48,484: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch013/validation_results.p
# 2024-05-03 17:04:48,486: Epoch 13 average validation loss: 23.23319 -- Median validation metrics: avg_loss: 23.23319, KGE: -0.04989
# # Epoch 14: 100% 1637/1637 [00:27<00:00, 58.69it/s, Loss: 2.2742]
# 2024-05-03 17:05:16,383: Epoch 14 average loss: avg_loss: 1.82828, avg_total_loss: 1.82828
# # Validation: 100% 8/8 [00:03<00:00,  2.49it/s]
# 2024-05-03 17:05:20,407: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch014/validation_metrics.csv
# 2024-05-03 17:05:20,420: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch014/validation_results.p
# 2024-05-03 17:05:20,422: Epoch 14 average validation loss: 23.83858 -- Median validation metrics: avg_loss: 23.83858, KGE: -0.05655
# # Epoch 15: 100% 1637/1637 [00:27<00:00, 59.93it/s, Loss: 1.0597]
# 2024-05-03 17:05:47,743: Epoch 15 average loss: avg_loss: 1.82443, avg_total_loss: 1.82443
# # Validation: 100% 8/8 [00:03<00:00,  2.45it/s]
# 2024-05-03 17:05:51,835: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch015/validation_metrics.csv
# 2024-05-03 17:05:51,848: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch015/validation_results.p
# 2024-05-03 17:05:51,850: Epoch 15 average validation loss: 23.04625 -- Median validation metrics: avg_loss: 23.04625, KGE: -0.02224
# # Epoch 16: 100% 1637/1637 [00:28<00:00, 58.39it/s, Loss: 2.5236]
# 2024-05-03 17:06:19,893: Epoch 16 average loss: avg_loss: 1.78452, avg_total_loss: 1.78452
# # Validation: 100% 8/8 [00:03<00:00,  2.57it/s]
# 2024-05-03 17:06:23,871: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch016/validation_metrics.csv
# 2024-05-03 17:06:23,883: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch016/validation_results.p
# 2024-05-03 17:06:23,885: Epoch 16 average validation loss: 23.06472 -- Median validation metrics: avg_loss: 23.06472, KGE: 0.05715
# # Epoch 17: 100% 1637/1637 [00:28<00:00, 57.86it/s, Loss: 1.5629]
# 2024-05-03 17:06:52,180: Epoch 17 average loss: avg_loss: 1.76854, avg_total_loss: 1.76854
# # Validation: 100% 8/8 [00:03<00:00,  2.39it/s]
# 2024-05-03 17:06:56,544: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch017/validation_metrics.csv
# 2024-05-03 17:06:56,557: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch017/validation_results.p
# 2024-05-03 17:06:56,560: Epoch 17 average validation loss: 22.87522 -- Median validation metrics: avg_loss: 22.87522, KGE: 0.01560
# # Epoch 18: 100% 1637/1637 [00:28<00:00, 58.38it/s, Loss: 1.3043]
# 2024-05-03 17:07:24,607: Epoch 18 average loss: avg_loss: 1.74176, avg_total_loss: 1.74176
# # Validation: 100% 8/8 [00:03<00:00,  2.46it/s]
# 2024-05-03 17:07:28,712: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch018/validation_metrics.csv
# 2024-05-03 17:07:28,733: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch018/validation_results.p
# 2024-05-03 17:07:28,735: Epoch 18 average validation loss: 23.81900 -- Median validation metrics: avg_loss: 23.81900, KGE: -0.00528
# # Epoch 19: 100% 1637/1637 [00:27<00:00, 59.11it/s, Loss: 0.9422]
# 2024-05-03 17:07:56,432: Epoch 19 average loss: avg_loss: 1.72680, avg_total_loss: 1.72680
# # Validation: 100% 8/8 [00:03<00:00,  2.51it/s]
# 2024-05-03 17:08:00,475: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch019/validation_metrics.csv
# 2024-05-03 17:08:00,487: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch019/validation_results.p
# 2024-05-03 17:08:00,489: Epoch 19 average validation loss: 24.29988 -- Median validation metrics: avg_loss: 24.29988, KGE: -0.02634
# 2024-05-03 17:08:00,489: Setting learning rate to 0.0001
# # Epoch 20: 100% 1637/1637 [00:28<00:00, 56.99it/s, Loss: 1.6905]
# 2024-05-03 17:08:29,220: Epoch 20 average loss: avg_loss: 1.61425, avg_total_loss: 1.61425
# # Validation: 100% 8/8 [00:03<00:00,  2.44it/s]
# 2024-05-03 17:08:33,382: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch020/validation_metrics.csv
# 2024-05-03 17:08:33,395: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch020/validation_results.p
# 2024-05-03 17:08:33,397: Epoch 20 average validation loss: 23.88883 -- Median validation metrics: avg_loss: 23.88883, KGE: -0.00943
# # Epoch 21: 100% 1637/1637 [00:27<00:00, 58.59it/s, Loss: 6.2721]
# 2024-05-03 17:09:01,342: Epoch 21 average loss: avg_loss: 1.59272, avg_total_loss: 1.59272
# # Validation: 100% 8/8 [00:03<00:00,  2.38it/s]
# 2024-05-03 17:09:05,591: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch021/validation_metrics.csv
# 2024-05-03 17:09:05,608: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch021/validation_results.p
# 2024-05-03 17:09:05,611: Epoch 21 average validation loss: 23.81760 -- Median validation metrics: avg_loss: 23.81760, KGE: -0.00271
# # Epoch 22: 100% 1637/1637 [00:28<00:00, 56.82it/s, Loss: 1.7844]
# 2024-05-03 17:09:34,425: Epoch 22 average loss: avg_loss: 1.57874, avg_total_loss: 1.57874
# # Validation: 100% 8/8 [00:03<00:00,  2.49it/s]
# 2024-05-03 17:09:38,513: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch022/validation_metrics.csv
# 2024-05-03 17:09:38,527: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch022/validation_results.p
# 2024-05-03 17:09:38,529: Epoch 22 average validation loss: 24.04620 -- Median validation metrics: avg_loss: 24.04620, KGE: -0.00447
# # Epoch 23: 100% 1637/1637 [00:29<00:00, 56.04it/s, Loss: 1.8355]
# 2024-05-03 17:10:07,747: Epoch 23 average loss: avg_loss: 1.57294, avg_total_loss: 1.57294
# # Validation: 100% 8/8 [00:03<00:00,  2.42it/s]
# 2024-05-03 17:10:11,913: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch023/validation_metrics.csv
# 2024-05-03 17:10:11,928: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch023/validation_results.p
# 2024-05-03 17:10:11,930: Epoch 23 average validation loss: 23.63926 -- Median validation metrics: avg_loss: 23.63926, KGE: -0.00851
# # Epoch 24: 100% 1637/1637 [00:31<00:00, 51.85it/s, Loss: 1.3521]
# 2024-05-03 17:10:43,506: Epoch 24 average loss: avg_loss: 1.56301, avg_total_loss: 1.56301
# # Validation: 100% 8/8 [00:03<00:00,  2.07it/s]
# 2024-05-03 17:10:48,319: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch024/validation_metrics.csv
# 2024-05-03 17:10:48,337: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch024/validation_results.p
# 2024-05-03 17:10:48,339: Epoch 24 average validation loss: 23.65034 -- Median validation metrics: avg_loss: 23.65034, KGE: -0.01772
# # Epoch 25: 100% 1637/1637 [00:28<00:00, 57.46it/s, Loss: 1.1398]
# 2024-05-03 17:11:16,836: Epoch 25 average loss: avg_loss: 1.55852, avg_total_loss: 1.55852
# # Validation: 100% 8/8 [00:03<00:00,  2.43it/s]
# 2024-05-03 17:11:21,058: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch025/validation_metrics.csv
# 2024-05-03 17:11:21,071: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch025/validation_results.p
# 2024-05-03 17:11:21,073: Epoch 25 average validation loss: 23.78851 -- Median validation metrics: avg_loss: 23.78851, KGE: 0.01486
# # Epoch 26: 100% 1637/1637 [00:28<00:00, 57.59it/s, Loss: 1.9503]
# 2024-05-03 17:11:49,501: Epoch 26 average loss: avg_loss: 1.55761, avg_total_loss: 1.55761
# # Validation: 100% 8/8 [00:03<00:00,  2.57it/s]
# 2024-05-03 17:11:53,487: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch026/validation_metrics.csv
# 2024-05-03 17:11:53,500: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch026/validation_results.p
# 2024-05-03 17:11:53,502: Epoch 26 average validation loss: 24.06744 -- Median validation metrics: avg_loss: 24.06744, KGE: -0.01964
# # Epoch 27: 100% 1637/1637 [00:28<00:00, 58.01it/s, Loss: 1.7953]
# 2024-05-03 17:12:21,723: Epoch 27 average loss: avg_loss: 1.54958, avg_total_loss: 1.54958
# # Validation: 100% 8/8 [00:03<00:00,  2.41it/s]
# 2024-05-03 17:12:25,909: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch027/validation_metrics.csv
# 2024-05-03 17:12:25,922: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch027/validation_results.p
# 2024-05-03 17:12:25,924: Epoch 27 average validation loss: 24.12414 -- Median validation metrics: avg_loss: 24.12414, KGE: -0.02580
# # Epoch 28: 100% 1637/1637 [00:28<00:00, 57.29it/s, Loss: 1.9314]
# 2024-05-03 17:12:54,504: Epoch 28 average loss: avg_loss: 1.54115, avg_total_loss: 1.54115
# # Validation: 100% 8/8 [00:03<00:00,  2.51it/s]
# 2024-05-03 17:12:58,581: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch028/validation_metrics.csv
# 2024-05-03 17:12:58,595: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch028/validation_results.p
# 2024-05-03 17:12:58,597: Epoch 28 average validation loss: 24.11581 -- Median validation metrics: avg_loss: 24.11581, KGE: 0.00579
# # Epoch 29: 100% 1637/1637 [00:28<00:00, 56.99it/s, Loss: 2.7287]
# 2024-05-03 17:13:27,326: Epoch 29 average loss: avg_loss: 1.54718, avg_total_loss: 1.54718
# # Validation: 100% 8/8 [00:03<00:00,  2.30it/s]
# 2024-05-03 17:13:32,037: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch029/validation_metrics.csv
# 2024-05-03 17:13:32,054: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch029/validation_results.p
# 2024-05-03 17:13:32,057: Epoch 29 average validation loss: 24.14104 -- Median validation metrics: avg_loss: 24.14104, KGE: -0.02675
# # Epoch 30: 100% 1637/1637 [00:30<00:00, 53.13it/s, Loss: 1.6717]
# 2024-05-03 17:14:02,875: Epoch 30 average loss: avg_loss: 1.54542, avg_total_loss: 1.54542
# # Validation: 100% 8/8 [00:03<00:00,  2.21it/s]
# 2024-05-03 17:14:07,635: Stored metrics at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch030/validation_metrics.csv
# 2024-05-03 17:14:07,656: Stored results at /home/casadje/neuralhydrology/models/ResOpsES/hydropower/runs/V_lstm64_fc32_do05_0305_165754/validation/model_epoch030/validation_results.p
# 2024-05-03 17:14:07,659: Epoch 30 average validation loss: 24.27391 -- Median validation metrics: avg_loss: 24.27391, KGE: -0.02076

# %% [markdown]
# ### Simulación

# %%
# find the directory of the last run
root_run_dir = cfg.run_dir if cfg.run_dir else Path('./runs/')
run_dir = max([x for x in root_run_dir.iterdir() if x.is_dir() & x.stem.startswith(cfg.experiment_name)])

print(run_dir)
# Out:
# runs/V_lstm64_fc32_do05_0305_165754

# %%
# # extraer el rendimiento de cada época y muestra
# metrics = pd.DataFrame(columns=range(1, cfg.epochs + 1))
# for epoch in tqdm(metrics.columns):
#     try:
#         _, metrics[epoch] = get_results(run_dir, 'validation', epoch=epoch)
#     except:
#         continue

# best_epoch = metrics.median().idxmax()
# print('mejor época: {0}\t\tKGE = {1:.3f}'.format(best_epoch, metrics.median().max()))

# %%
for period in ['train']:#, 'test']:
    if run_all:
        for epoch in np.arange(1, cfg.epochs + 1):
            if torch.cuda.is_available(): # con GPU
                eval_run(run_dir=run_dir, period=period, epoch=epoch, gpu=0)
            else: # con CPU
                eval_run(run_dir=run_dir, period=period, epoch=epoch, gpu=-1)
    else:
        if torch.cuda.is_available(): # con GPU
            eval_run(run_dir=run_dir, period=period, epoch=best_epoch, gpu=0)
        else: # con CPU
            eval_run(run_dir=run_dir, period=period, epoch=best_epoch, gpu=-1)
# Out:
# 2024-05-03 17:14:07,852: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch001.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.53it/s]
# 2024-05-03 17:14:20,917: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch001/train_metrics.csv
# 2024-05-03 17:14:20,955: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch001/train_results.p
# 2024-05-03 17:14:21,001: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch002.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.57it/s]
# 2024-05-03 17:14:33,875: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch002/train_metrics.csv
# 2024-05-03 17:14:33,910: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch002/train_results.p
# 2024-05-03 17:14:33,939: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch003.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.47it/s]
# 2024-05-03 17:14:47,547: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch003/train_metrics.csv
# 2024-05-03 17:14:47,581: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch003/train_results.p
# 2024-05-03 17:14:47,614: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch004.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.47it/s]
# 2024-05-03 17:15:01,231: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch004/train_metrics.csv
# 2024-05-03 17:15:01,269: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch004/train_results.p
# 2024-05-03 17:15:01,300: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch005.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.47it/s]
# 2024-05-03 17:15:14,898: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch005/train_metrics.csv
# 2024-05-03 17:15:14,931: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch005/train_results.p
# 2024-05-03 17:15:14,953: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch006.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.51it/s]
# 2024-05-03 17:15:28,252: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch006/train_metrics.csv
# 2024-05-03 17:15:28,281: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch006/train_results.p
# 2024-05-03 17:15:28,303: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch007.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.54it/s]
# 2024-05-03 17:15:41,313: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch007/train_metrics.csv
# 2024-05-03 17:15:41,355: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch007/train_results.p
# 2024-05-03 17:15:41,384: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch008.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.52it/s]
# 2024-05-03 17:15:54,543: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch008/train_metrics.csv
# 2024-05-03 17:15:54,591: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch008/train_results.p
# 2024-05-03 17:15:54,611: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch009.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.49it/s]
# 2024-05-03 17:16:08,025: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch009/train_metrics.csv
# 2024-05-03 17:16:08,056: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch009/train_results.p
# 2024-05-03 17:16:08,096: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch010.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.57it/s]
# 2024-05-03 17:16:20,850: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch010/train_metrics.csv
# 2024-05-03 17:16:20,882: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch010/train_results.p
# 2024-05-03 17:16:20,903: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch011.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.50it/s]
# 2024-05-03 17:16:34,216: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch011/train_metrics.csv
# 2024-05-03 17:16:34,256: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch011/train_results.p
# 2024-05-03 17:16:34,290: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch012.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.49it/s]
# 2024-05-03 17:16:47,741: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch012/train_metrics.csv
# 2024-05-03 17:16:47,766: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch012/train_results.p
# 2024-05-03 17:16:47,787: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch013.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.49it/s]
# 2024-05-03 17:17:01,238: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch013/train_metrics.csv
# 2024-05-03 17:17:01,268: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch013/train_results.p
# 2024-05-03 17:17:01,309: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch014.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.63it/s]
# 2024-05-03 17:17:13,607: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch014/train_metrics.csv
# 2024-05-03 17:17:13,638: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch014/train_results.p
# 2024-05-03 17:17:13,666: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch015.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.63it/s]
# 2024-05-03 17:17:25,924: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch015/train_metrics.csv
# 2024-05-03 17:17:25,960: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch015/train_results.p
# 2024-05-03 17:17:25,994: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch016.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.61it/s]
# 2024-05-03 17:17:38,444: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch016/train_metrics.csv
# 2024-05-03 17:17:38,468: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch016/train_results.p
# 2024-05-03 17:17:38,491: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch017.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.62it/s]
# 2024-05-03 17:17:50,816: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch017/train_metrics.csv
# 2024-05-03 17:17:50,847: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch017/train_results.p
# 2024-05-03 17:17:50,867: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch018.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.62it/s]
# 2024-05-03 17:18:03,216: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch018/train_metrics.csv
# 2024-05-03 17:18:03,244: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch018/train_results.p
# 2024-05-03 17:18:03,270: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch019.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.51it/s]
# 2024-05-03 17:18:16,503: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch019/train_metrics.csv
# 2024-05-03 17:18:16,531: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch019/train_results.p
# 2024-05-03 17:18:16,553: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch020.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.44it/s]
# 2024-05-03 17:18:30,461: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch020/train_metrics.csv
# 2024-05-03 17:18:30,496: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch020/train_results.p
# 2024-05-03 17:18:30,530: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch021.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.43it/s]
# 2024-05-03 17:18:44,532: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch021/train_metrics.csv
# 2024-05-03 17:18:44,564: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch021/train_results.p
# 2024-05-03 17:18:44,588: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch022.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.51it/s]
# 2024-05-03 17:18:57,857: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch022/train_metrics.csv
# 2024-05-03 17:18:57,889: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch022/train_results.p
# 2024-05-03 17:18:57,919: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch023.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.60it/s]
# 2024-05-03 17:19:10,440: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch023/train_metrics.csv
# 2024-05-03 17:19:10,471: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch023/train_results.p
# 2024-05-03 17:19:10,493: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch024.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.58it/s]
# 2024-05-03 17:19:23,124: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch024/train_metrics.csv
# 2024-05-03 17:19:23,152: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch024/train_results.p
# 2024-05-03 17:19:23,175: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch025.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.53it/s]
# 2024-05-03 17:19:36,225: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch025/train_metrics.csv
# 2024-05-03 17:19:36,257: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch025/train_results.p
# 2024-05-03 17:19:36,281: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch026.pt
# # Evaluation: 100% 20/20 [00:13<00:00,  1.47it/s]
# 2024-05-03 17:19:49,896: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch026/train_metrics.csv
# 2024-05-03 17:19:49,927: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch026/train_results.p
# 2024-05-03 17:19:49,952: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch027.pt
# # Evaluation: 100% 20/20 [00:11<00:00,  1.67it/s]
# 2024-05-03 17:20:01,945: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch027/train_metrics.csv
# 2024-05-03 17:20:01,974: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch027/train_results.p
# 2024-05-03 17:20:01,996: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch028.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.60it/s]
# 2024-05-03 17:20:14,542: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch028/train_metrics.csv
# 2024-05-03 17:20:14,577: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch028/train_results.p
# 2024-05-03 17:20:14,601: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch029.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.62it/s]
# 2024-05-03 17:20:26,935: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch029/train_metrics.csv
# 2024-05-03 17:20:26,967: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch029/train_results.p
# 2024-05-03 17:20:26,989: Using the model weights from runs/V_lstm64_fc32_do05_0305_165754/model_epoch030.pt
# # Evaluation: 100% 20/20 [00:12<00:00,  1.56it/s]
# 2024-05-03 17:20:39,841: Stored metrics at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch030/train_metrics.csv
# 2024-05-03 17:20:39,872: Stored results at runs/V_lstm64_fc32_do05_0305_165754/train/model_epoch030/train_results.p

# %% [markdown]
# ## Results
#
# ### Evolution of training and validation

# %%
# extraer el rendimiento de cada época y muestra
metrics = {period: pd.DataFrame(columns=range(1, cfg.epochs + 1)) for period in ['train', 'validation']} # ['train', 'validation', 'test']}
for period, df in tqdm(metrics.items(), desc='period'):
    for epoch in df.columns:
        try:
            _, df[epoch] = get_results(run_dir, period, epoch=epoch)
        except:
            continue
# Out:
# period:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
import matplotlib.patches as mpatches

# %%
fig, ax = plt.subplots(figsize=(20, 5))

colors = ['steelblue', 'indianred', 'khaki']
patches = []
for i, ((period, df), c) in enumerate(zip(metrics.items(), colors)):
    bp = ax.boxplot(df, positions=df.columns + i * .25, widths=0.25,
                    patch_artist=True,
                    boxprops={'color': c, 'alpha': .5},
                    # whiskerprops={},
                    showfliers=False,
                    medianprops={'color': 'k'})
    for box in bp['boxes']:
        box.set_facecolor(c)
    patches.append(mpatches.Patch(color=c, alpha=.5, label=period))

# ax.set_ylim(-1, 1);
xticks = np.linspace(1, cfg.epochs, num=cfg.epochs).astype(int)
ax.set_xticks(xticks)
ax.set_xticklabels(xticks)
ax.set(xlabel='epoch (-)',
       ylabel=f'{cfg.metrics[0]} (-)');

ax.legend(handles=patches, frameon=False, bbox_to_anchor=[1, .35, .1, .3]);

plt.savefig(run_dir / 'evolucion_KGE.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Best epoch

# %%
# mejor época de cada muestra y el rendimiento de cada muestra en esa época
best_epoch = {}
for period, df in metrics.items():
    epoch = df.median().idxmax()
    best_epoch[period] = epoch
    print('epoch {0:>2}:\tKGEtrain = {1:.3f}   KGEval = {2:.3f}'.format(epoch,
                                                                        metrics['train'][epoch].median(),
                                                                        metrics['validation'][epoch].median()))
epoch = best_epoch['validation']
# Out:
# epoch 27:	KGEtrain = 0.908   KGEval = -0.026
# epoch  4:	KGEtrain = 0.735   KGEval = 0.131

# %%
# rendimiento y series simuladas de la mejor época
series = {}
rendimiento = pd.DataFrame()
for period in ['train', 'validation']:
    # importar resultados
    series_period, rend_period = get_results(run_dir, period, epoch=epoch)
    rend_period.columns = [period]
    series[period] = series_period
    rendimiento = pd.concat((rendimiento, rend_period), axis=1)

# %%
# hidrogramas
# if hidrogramas:
for period, dct in series.items():
    path = run_dir / 'plots' / period
    path.mkdir(parents=True, exist_ok=True)
    plot_results(dct, period, target=cfg.target_variables[0], ylim=(-.05, 1.05), ylabel='fraction filled (-)', save=None)#path)
# Out:
# /home/casadje/neuralhydrology/models/ResOpsES/hydropower/../../model_utils.py:171: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=figsize)#, sharex=True, sharey=True)
